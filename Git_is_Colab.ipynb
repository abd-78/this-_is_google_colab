# %% [markdown]
# <a href="https://colab.research.google.com/github/abd-78/this-_is_google_colab/blob/main/Git_is_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
